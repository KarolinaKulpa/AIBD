# %% [markdown]
# **Karolina Kulpa - Analiza i Bazy Danych laboratorium 1**

# %% [markdown]
# **Zadanie 3**
#
# Zdefiniuj poniższą funkcję i sporządź jej wykres dla argumentów z danego przedziału:
#
# $f(x)=x^2+5$
#
# $x>-1 \ oraz \ x<1$
#
# $x>-6 \  oraz \ x<6$
#
# $x>0 \ oraz \ x<5$
#
# Wspierając się dokumentacją Matplotlib. Dodaj do wykresu etykiety osi, tytuły wykresów i legendy.
#
# Wskazówki: Deklaracja funkcji w Python.
#
# W Pythonie bloki kodu (w tym również funkcje) są wyróżniane za pomocą wcięć. Do wizualizacji wyników w Pythonie używa się pakietu Matplotlib.

# %%
# importowanie wymaganych bibliotek
import numpy as np
import matplotlib.pyplot as plt


# definicja funkcji odpowiadającej za obliczanie i rysowanie wykresu
def fun(x1,x2):
    x = np.linspace(x1, x2, 500)
    y = x**2+5

    plt.plot(x,y)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Wykres')
    plt.grid(True)
    plt.show()

#rysowanie wykresów
fun(-1,1)
fun(-6,6)
fun(0,5)

# %% [markdown]
# **Zadanie 4**
#
# Utwórz dataframe, w którym kolumny mają nazwy: name, surname, age, sex. Uzupełnij pięcioma dowolnymi rekordami oraz wyświetl informacje o danych pandas .info(), opis danych pandas .describe(), wyświetl pierwsze trzy rekordy pandas .head().

# %%
#importowanie wymaganych bibliotek
import pandas as pd 

#stworzenie dataframe z danymi
df = pd.DataFrame(np.array([['Karolina', 'Kulpa', 22, 'female'], 
                            ['Adam', 'Kowalski', 30, 'male'],
                            ['Anna', 'Nowak', 40, 'female'],
                            ['Adam', 'Mickiewicz', 38, 'male'],
                            ['Jan', 'Kochanowski', 32, 'male']]),columns=['name', 'surname', 'age', 'sex'])


#wyświetlenie informacji o danych oraz informacji statystycznych
print(df.info())
print(df.describe())

#wyświetlenie 3 pierwszych rekordów
df.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     5 non-null      object
#  1   surname  5 non-null      object
#  2   age      5 non-null      object
#  3   sex      5 non-null      object
# dtypes: object(4)
# memory usage: 288.0+ bytes
# None
#         name surname age   sex
# count      5       5   5     5
# unique     4       5   5     2
# top     Adam   Kulpa  32  male
# freq       2       1   1     3
#        name   surname age     sex
# 0  Karolina     Kulpa  22  female
# 1      Adam  Kowalski  30    male
# 2      Anna     Nowak  40  female
